# %% [markdown]
# <a href="https://colab.research.google.com/github/r-vdw/git_practice/blob/master/dag1Trebuchet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dag 1 trebuchet: deel 1


inputCalibratie = []
with open('dag1.txt', 'r') as inputDag1:
    for x in inputDag1:
      inputCalibratie.append(x)

print(inputCalibratie)


inputDeel1 = ["1abc2", "pqr3stu8vwx", "a1b2c3d4e5f", "treb7uchet"]


def calibratie(tekst):
  waarden = []
  waardenTuple = []
  for lijn in tekst:
    #print(lijn)
    waarde_eerst = 0
    waarde_laatst = 0

    for letter in lijn:
      if letter.isdigit():
        if waarde_eerst == 0:
          waarde_eerst = int(letter)
          waarde_laatst = int(letter)
        else:
          waarde_laatst = int(letter)

    #print(waarde_eerst, waarde_laatst)


    waarde = int(str(waarde_eerst) + str(waarde_laatst))
    waarden.append(waarde)
    waardenTuple.append((waarde_eerst, waarde_laatst))

  return (sum(waarden), len(waarden), len(waardenTuple), waardenTuple )

print(calibratie(inputDeel1))
print(calibratie(inputCalibratie))
# Out:
# ['99lbqpxzzlbtvkmfrvrnmcxttseven\n', 'q7cnfslbtpkvseven\n', '6threezlljtzcr1sdjkthree4cx\n', '21xfxfourmzmqbqp1\n', 'lkdbjd5\n', '8three27\n', '21three\n', '3lqrzdq16\n', '49threenjdgrmgfnfhcgz\n', 'fourmsmjqfmbjvtwosevendcljsdcstl3one\n', 'four98\n', '4sevenfddxgcvdgx\n', 'dffmkvmhhdbzjcgrjc5132\n', 'eight4one31nxlnrzvtfvrkfvgbbqmvff\n', 'mdmvbhqjt5rkfpcnfvzhkkfbjvh8three9\n', 'four32\n', 'seven6pljhqnineeightjjsvnqblk8eight\n', '6glzfour77fiveone\n', 'ntvhxqzsixxcrfpgstwo915onevxz\n', '81four8xkttczb2vj\n', 'six8flfzdzl72eightnine\n', 'sevensevenzsztgvh4sixbzltzl\n', '2fivehgrszcrgc9\n', 'four53ninedrjllgffrfrtjgggvknine\n', 'nineonecxpzzqsptc7nv9pck\n', 'sixrqqfkcjrqkppvqthree1\n', '1five72cxh3fivefive\n', '75349sixnhxjpgtnhqlf\n', '9963onefourthree6oneightq\n', '51fp\n', 'foursix2lt7one1sevenone\n', 'fourddcmgbvkm8fivethreeksqghch65ztdtsdmpvk\n', '35jxmgctsevennine\n', 'mbbkjxfthreetwoqlcrjnlvkrgnine41vkjknnmtv\n', 'three7sixtwohpghsdxleightthreetwo5\n', 'twocbtbkxhhcdrctkc14hlmd
# ...

# %%
#dag 1 trebuchet: deel 2


inputCalibratie = []
with open('dag1.txt', 'r') as inputDag1:
    for x in inputDag1:
      inputCalibratie.append(x)

print(inputCalibratie)


inputDeel1 = ["1abc2", "pqr3stu8vwx", "a1b2c3d4e5f", "treb7uchet"]
inputDeel2 = ["two1nine", "eightwothree", "abcone2threexyz", "xtwone3four", "4nineeightseven2", "zoneight234", "7pqrstsixteen"]
print(inputDeel2)

cijfers = {"one":1, "two":2, "three":3, "four":4, "five":5, "six":6, "seven":7, "eight":8, "nine":9}


def calibratie(tekst):
  waardenEnkelGetallen = []
  waardenGetallenEnCijfers = []
  waardenTuple = []
  for lijn in tekst:
    #print(lijn)
    waarde_eerst = 0
    waarde_laatst = 0
    cijferInLetters_eerst = "x"
    cijferInLetters_laatst = "x"
    for letter in lijn:
      if letter.isdigit():
        if waarde_eerst == 0:
          waarde_eerst = int(letter)
          waarde_laatst = int(letter)
        else:
          waarde_laatst = int(letter)

    waarde_eerst_index = lijn.find(str(waarde_eerst))
    waarde_laatst_index = lijn.rfind(str(waarde_laatst))

    index_cijferInLetters_eerst = len(lijn) -1
    index_cijferInLetters_laatst = 0
    for cijfer in cijfers:
      indexFind = lijn.find(cijfer)
      indexRFind = lijn.rfind(cijfer)
      if indexFind != -1 and indexFind < index_cijferInLetters_eerst:
        index_cijferInLetters_eerst = indexFind
        woord_cijferInLetters_eerst = cijfer
       #print(indexFind)
      if indexRFind != -1 and indexRFind > index_cijferInLetters_laatst:
        index_cijferInLetters_laatst = indexRFind
        woord_cijferInLetters_laatst = cijfer


    if index_cijferInLetters_eerst < waarde_eerst_index:
      waarde_eerst_def = cijfers[woord_cijferInLetters_eerst]
    else:
      waarde_eerst_def = waarde_eerst

    if index_cijferInLetters_laatst > waarde_laatst_index:
      waarde_laatst_def = cijfers[woord_cijferInLetters_laatst]
    else:
      waarde_laatst_def = waarde_laatst


    #print(waarde_eerst_def, waarde_laatst_def, waarde_eerst, waarde_eerst_index, waarde_laatst, waarde_laatst_index, index_cijferInLetters_eerst, woord_cijferInLetters_eerst, index_cijferInLetters_laatst, woord_cijferInLetters_laatst)


    waardeEnkelGetallen = int(str(waarde_eerst) + str(waarde_laatst))
    waardeGetallenEnCijfers = int(str(waarde_eerst_def) + str(waarde_laatst_def))
   # print(waarde)
    waardenEnkelGetallen.append(waardeEnkelGetallen)
    waardenTuple.append((waarde_eerst, waarde_laatst))
    waardenGetallenEnCijfers.append(waardeGetallenEnCijfers)


  return (sum(waardenGetallenEnCijfers), len(waardenGetallenEnCijfers), sum(waardenEnkelGetallen) , len(waardenEnkelGetallen), len(waardenTuple), waardenTuple )

print(calibratie(inputDeel2))
print(calibratie(inputCalibratie))
# Out:
# ['99lbqpxzzlbtvkmfrvrnmcxttseven\n', 'q7cnfslbtpkvseven\n', '6threezlljtzcr1sdjkthree4cx\n', '21xfxfourmzmqbqp1\n', 'lkdbjd5\n', '8three27\n', '21three\n', '3lqrzdq16\n', '49threenjdgrmgfnfhcgz\n', 'fourmsmjqfmbjvtwosevendcljsdcstl3one\n', 'four98\n', '4sevenfddxgcvdgx\n', 'dffmkvmhhdbzjcgrjc5132\n', 'eight4one31nxlnrzvtfvrkfvgbbqmvff\n', 'mdmvbhqjt5rkfpcnfvzhkkfbjvh8three9\n', 'four32\n', 'seven6pljhqnineeightjjsvnqblk8eight\n', '6glzfour77fiveone\n', 'ntvhxqzsixxcrfpgstwo915onevxz\n', '81four8xkttczb2vj\n', 'six8flfzdzl72eightnine\n', 'sevensevenzsztgvh4sixbzltzl\n', '2fivehgrszcrgc9\n', 'four53ninedrjllgffrfrtjgggvknine\n', 'nineonecxpzzqsptc7nv9pck\n', 'sixrqqfkcjrqkppvqthree1\n', '1five72cxh3fivefive\n', '75349sixnhxjpgtnhqlf\n', '9963onefourthree6oneightq\n', '51fp\n', 'foursix2lt7one1sevenone\n', 'fourddcmgbvkm8fivethreeksqghch65ztdtsdmpvk\n', '35jxmgctsevennine\n', 'mbbkjxfthreetwoqlcrjnlvkrgnine41vkjknnmtv\n', 'three7sixtwohpghsdxleightthreetwo5\n', 'twocbtbkxhhcdrctkc14hlmd
# ...
